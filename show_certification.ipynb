# %%
import pandas as pd
#load excel file
for psr in [0.2,0.3,0.4,0.5,1.0,1.5]:
    df = pd.read_excel(f'certification_robust_adv_training_noise_psr_{psr}_std_1_defult_lab_276..xlsx')
    df = df[df['prediction'] != -1]

    print(f'PSR:{psr}, accuracy: ', (df['prediction'] == df['y']).sum()/len(df))
# Out:
# PSR:0.2, accuracy:  0.97911227154047
# PSR:0.3, accuracy:  0.9851485148514851
# PSR:0.4, accuracy:  0.9806763285024155
# PSR:0.5, accuracy:  0.9881796690307328
# PSR:1.0, accuracy:  0.9245283018867925
# PSR:1.5, accuracy:  0.8588957055214724
