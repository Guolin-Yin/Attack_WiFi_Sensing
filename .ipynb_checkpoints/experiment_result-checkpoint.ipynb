# %%
from scipy.io import loadmat,savemat
from Pub_plots import *
from Adversarial_training import get_adv_data
from ATKMethods import generatePerturbData,AlexNetTF
from sklearn.model_selection import train_test_split
import numpy as np
import utils.gestureDataLoader as gestureDataLoader
import tensorflow as tf
import utils.Config as Config
import os
import random
def dict_clean(dict):
    for key in list(dict.keys()):
        if key.startswith('__'):
            del dict[key]
    return dict
config = Config.getconfig()

# %% [markdown]
# # Adversarial training results

# %% [markdown]
# ***1. Results path***
# * PGD attack with l2 norm:
#     `resultsMat/acc_all_adv_all_l2_pgd.mat`
# * PGD attack with l-infinite norm:
#     `resultsMat/acc_all_adv_all.mat`
#
# All the training conducted using L-infinite norm, since if using the l2 norm, the adversarial training will cause invalid gradient (nan or 0) at some point.
#
# ***2. The attacking methods:***
# * FGSM, PGD with 2,3,4,5,6,7,12 iterations
#
# ***3. Defense models training by***
# * Normal, FGSM, PGD with 2,3,4,5,6,7,12 iterations

# %% [markdown]
# ## Confusion matrix

# %%
path = 'resultsMat/acc_all_adv_all_paper_attack_methods.mat'
result = loadmat(path,squeeze_me=True)
dict_clean(result)
hp_plotter_defense(result,-6,'asr')

# %% [markdown]
# ## Line figure

# %%
result = loadmat('resultsMat/acc_all_adv_all_paper_attack_methods.mat',squeeze_me=True)
N = -1
atk = 'pgd_4'
info = {
    'psr'           : result['psr'][0:N],
    'resnet_FGSM'   : result[f'resnet_pgd_4_0.0005_defense_against_fgsm_None'][0:N],
    'resnet_2'      : result[f'resnet_pgd_4_0.0005_defense_against_pgd_2'][0:N],
    # 'resnet_3'      : result[f'resnet_pgd_4_0.0005_defense_against_pgd_3'][0:N],
    'resnet_4'      : result[f'resnet_pgd_4_0.0005_defense_against_pgd_4'][0:N],
    # 'resnet_5'      : result[f'resnet_pgd_4_0.0005_defense_against_pgd_5'][0:N],
    # 'resnet_6'      : result[f'resnet_pgd_4_0.0005_defense_against_pgd_6'][0:N],
    # 'resnet_7'      : result[f'resnet_pgd_4_0.0005_defense_against_pgd_7'][0:N],
    'resnet_12'     : result[f'resnet_pgd_4_0.0005_defense_against_pgd_12'][0:N],
    # 'resnet_0.001_4':result[f'resnet_pgd_4_0.001_defense_against_{atk}'][0:N],
    # 'Normal':result[f'Normal_defense_against_{atk}'][0:N],
    # 'FGSM':result[f'fgsm_None_defense_against_{atk}'][0:N],

}

marker_dic = {}
[marker_dic.update({key:marker}) for key,marker in zip(info.keys(),['o','s','^','v','<','>','*','+','x','d'])]

plot_adv_results(config,info,None,'asr',marker_dic = marker_dic)

# %% [markdown]
# ## Plot 3D loss of adversarial trained model

# %%
random.seed(42)
config.source = 'lab_276'
assert config.source != None, 'source should not be None'
train_data, test_data, train_label, test_label = gestureDataLoader.getData(
        config, 'signfi'
        )

X_train, X_test, y_train, y_test = train_test_split( train_data, train_label, test_size=0.1, random_state=42)


net = AlexNetTF( config )
model = net.buildModel( choice = 'defult')
# model.load_weights('SavedModel/Adversarial_robust_model/robust_adv_training_pgd_psr_0.0005_resnet_lab_276_niter_4_new.h5')
model.load_weights('SavedModel/Adversarial_robust_model/Normal.h5')
# Out:
# Loading data................

# %%
draw_loss(model,X_train[0:1],y_train[0:1],0.0005)
