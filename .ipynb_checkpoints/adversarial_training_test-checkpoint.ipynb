# %% [markdown]
# # 0. Imoprt packets

# %%
from Adversarial_training import get_adv_data,train_loop,test_loop
from ATKMethods import generatePerturbData,AlexNetTF
from scipy.io import loadmat,savemat
from sklearn.model_selection import train_test_split
import numpy as np
import utils.gestureDataLoader as gestureDataLoader
import tensorflow as tf
import os
import utils.Config as Config
import random
random.seed(42)
config = Config.getconfig( )
config.source = 'lab_276'
assert config.source != None, 'source should not be None'
train_data, test_data, train_label, test_label = gestureDataLoader.getData(
        config, 'signfi'
        )

X_train, X_test, y_train, y_test = train_test_split( train_data, train_label, test_size=0.1, random_state=42)
batch_size = config.batch_size
# Prepare the training dataset.
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

val_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
val_dataset = val_dataset.batch(batch_size)

test_dataset = tf.data.Dataset.from_tensor_slices((test_data, test_label))
test_dataset = test_dataset.batch(batch_size)
# Out:
# Loading data................
# 2022-09-30 13:58:15.851027: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-30 13:58:16.126666: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10106 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# # 1. Load Dataset

# %% [markdown]
# Load SignFi Dataset

# %%
config.source = 'lab_276'
assert config.source != None, 'source should not be None'
train_data, test_data, train_label, test_label = gestureDataLoader.getData(
        config, 'signfi'
        )

X_train, X_test, y_train, y_test = train_test_split( train_data, train_label, test_size=0.1, random_state=42)
batch_size = config.batch_size
# Prepare the training dataset.
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

val_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
val_dataset = val_dataset.batch(batch_size)

test_dataset = tf.data.Dataset.from_tensor_slices((test_data, test_label))
test_dataset = test_dataset.batch(batch_size)

# %% [markdown]
# # 2. Build Model

# %%
config.DNN_name = 'resnet'
config.epoch = 1000
psr = 0.001/2
method = 'pgd'
n_iter = 4
model_name = f'robust_adv_training_{method}_psr_{psr}_{config.DNN_name}_{config.source}_niter_{n_iter}_new.h5'
config.model_path['adv_robust_model_path'] = 'SavedModel/Adversarial_robust_model' 
config.model_path['adv_robust_model_path'] = os.path.join( config.model_path['adv_robust_model_path'], model_name)
net = AlexNetTF( config )
model = net.buildModel( choice = config.DNN_name)
print(config.model_path['adv_robust_model_path'])
print(f'The model existance? ',os.path.exists(config.model_path['adv_robust_model_path']))
# Out:
# SavedModel/Adversarial_robust_model/robust_adv_training_pgd_psr_0.0005_resnet_lab_276_niter_4_new.h5
# The model existance?  True

# %% [markdown]
# # 3. Adversarial Training

# %%
config.lr = 1e-4
model = train_loop(config,model,train_dataset,val_dataset,psr,method,n_iter = n_iter)

# %% [markdown]
# # Evaluation

# %%
# extract model training information
def extract_info(filename):
    filename = filename.replace('.h5','')
    if 'robust_adv_training' in filename:
        adv_training_method = filename.split('robust_adv_training_')[1].split('_')[0]
        psr = float(filename.split('psr_')[1].split('_')[0])
        model_name = filename.split('_')[6]
        n_iters = 'None' if 'fgsm' in filename else int(filename.split('niter_')[1].split('_')[0])
        return adv_training_method,psr,model_name,n_iters
    else:
        return 'Normal',None,model_name,None
# model_path_list = os.listdir('SavedModel/Adversarial_robust_model')
model_path_list = []
adv_model = '_'
for path in os.listdir('SavedModel/Adversarial_robust_model'):
    if adv_model in path:
        model_path_list.append(path)
# model_path_list = ['Normal.h5']
# print(model_path_list)

# Convert list to dictionary
model_path_dict = {}
for path in model_path_list:
    adv_training_method,psr,model_name,n_iters = extract_info(path)
    model_path_dict[f'{model_name}_{adv_training_method}_{n_iters}_{psr}'] = path

# %%
mat_path = 'resultsMat/acc_all_adv_all_paper_attack_methods.mat'
if os.path.exists(mat_path):
    acc_all_adv = loadmat(mat_path)
else:
    acc_all_adv = {}
for ATK in ['fgsm','pgd_2','pgd_3','pgd_4','pgd_5','pgd_6','pgd_7','pgd_12']:
    if ATK == 'fgsm':
        ATK_method = 'fgsm'
        iter = None
    else:
        ATK_method = ATK.split('_')[0]
        iter = int(ATK.split('_')[1])
     
    for _, model_path in model_path_dict.items():
        acc_buf = []
        adv_training_method,psr,model_name,train_iters = extract_info(model_path)
        config.DNN_name = model_name
        net = AlexNetTF( config )
        model = net.buildModel( choice = config.DNN_name)
        model.load_weights(os.path.join('SavedModel/Adversarial_robust_model',model_path))
        print(f'==========================================Attack method {ATK_method}  {iter}========================================================')
        out_key = f'{model_name}_{adv_training_method}_{train_iters}_{psr}_defense_against_{ATK_method}_{iter}'
        if out_key in acc_all_adv.keys():
            print('The result already exist')
            print(out_key)
            continue
        for psr_current in [ 0.0, 6.250e-05, 1.250e-04, 1.875e-04 ,2.500e-04 ,3.125e-04 ,3.750e-04, 4.375e-04, 5.000e-04, 1.000e-03 ,1.500e-03 ,3.000e-03, 4.000e-03, 5.000e-03]:
            
            test_acc = test_loop(config,psr_current,model,test_dataset,ATK_method,n_iter = iter)
            
            acc_buf.append( test_acc )
        print(f'Adversarial training model: {model_name} method: {adv_training_method} iters: {train_iters} psr: {psr} defense against {ATK_method} {iter} \n', )
        np.set_printoptions(precision=3)
        print(f'Accuracy: {np.asarray(acc_buf)*100}')
        acc_all_adv.update({ 
                            out_key: np.asarray(acc_buf)
                            } )
    savemat(mat_path,acc_all_adv)
# Out:
# ==========================================Attack method fgsm  None========================================================
# The result already exist
# resnet_pgd_4_0.0005_defense_against_fgsm_None
# ==========================================Attack method fgsm  None========================================================
# The result already exist
# defult_pgd_12_0.001_defense_against_fgsm_None
# ==========================================Attack method fgsm  None========================================================
# The result already exist
# defult_pgd_7_0.001_defense_against_fgsm_None
# ==========================================Attack method fgsm  None========================================================
# The result already exist
# defult_pgd_4_0.001_defense_against_fgsm_None
# ==========================================Attack method fgsm  None========================================================
# The result already exist
# defult_pgd_3_0.001_defense_against_fgsm_None
# ==========================================Attack method fgsm  None========================================================
# The result already exist
# resnet_pgd_4_0.001_defense_against_fgsm_None
# ==========================================Attack method fgsm  None========================================================
# The result already exist
# defult_fgsm_None_0.001_defense_against_fgsm_None
# ==========================================Attack method fgsm  None========================================================
# The result already exist
# defult_pgd_2_0.001_defense_against_fgsm_None
# ==========================================Attack method fgsm  None========================================================
# The result already exist
# defult_pgd_6_0.001_defense_against_fgsm_None
# ==========================================Attack method fgsm  None========================================================
# The result already exist
# defult_pgd_5_0.001_defense_against_fgsm_None
# ==========================================Attack method pgd  2========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.0005 defense against pgd 2
#
# Accuracy: [100.     99.638  99.275  99.004  98.279  97.101  95.924  94.112  92.301
#   72.011  50.634  22.373  16.757  13.134]
# ==========================================Attack method pgd  2========================================================
# Adversarial training model: defult method: pgd iters: 12 psr: 0.001 defense against pgd 2
#
# Accuracy: [90.851 84.058 77.899 73.37  69.022 64.946 61.504 57.699 53.714 37.047
#  29.529 18.75  15.036 12.5  ]
# ==========================================Attack method pgd  2========================================================
# Adversarial training model: defult method: pgd iters: 7 psr: 0.001 defense against pgd 2
#
# Accuracy: [86.413 83.786 82.337 80.072 77.536 75.181 72.645 70.743 68.116 51.54
#  41.938 25.906 20.743 17.12 ]
# ==========================================Attack method pgd  2========================================================
# Adversarial training model: defult method: pgd iters: 4 psr: 0.001 defense against pgd 2
#
# Accuracy: [88.768 86.141 82.428 77.627 72.645 68.478 64.946 60.507 56.793 37.5
#  27.174 15.127 11.685  9.692]
# ==========================================Attack method pgd  2========================================================
# Adversarial training model: defult method: pgd iters: 3 psr: 0.001 defense against pgd 2
#
# Accuracy: [86.594 84.964 82.156 78.533 74.728 71.105 67.391 63.043 58.333 40.217
#  28.986 18.569 14.855 13.225]
# ==========================================Attack method pgd  2========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.001 defense against pgd 2
#
# Accuracy: [93.659 90.489 88.406 86.775 85.417 83.605 82.428 80.797 79.257 66.848
#  55.163 36.413 30.163 25.996]
# ==========================================Attack method pgd  2========================================================
# Adversarial training model: defult method: fgsm iters: None psr: 0.001 defense against pgd 2
#
# Accuracy: [86.413 83.786 82.337 81.159 79.62  77.808 75.906 74.185 72.283 59.783
#  50.272 30.344 21.286 16.486]
# ==========================================Attack method pgd  2========================================================
# Adversarial training model: defult method: pgd iters: 2 psr: 0.001 defense against pgd 2
#
# Accuracy: [91.757 86.866 80.344 75.906 71.377 67.754 64.493 60.96  57.699 40.761
#  31.522 19.022 15.217 13.496]
# ==========================================Attack method pgd  2========================================================
# Adversarial training model: defult method: pgd iters: 6 psr: 0.001 defense against pgd 2
#
# Accuracy: [89.221 85.417 80.525 75.906 71.83  68.388 63.859 59.692 55.888 37.228
#  28.623 17.482 13.768 11.866]
# ==========================================Attack method pgd  2========================================================
# Adversarial training model: defult method: pgd iters: 5 psr: 0.001 defense against pgd 2
#
# Accuracy: [85.417 82.79  78.08  73.732 69.112 64.493 59.783 56.431 52.355 35.236
#  25.996 14.04  12.138  9.239]
# ==========================================Attack method pgd  3========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.0005 defense against pgd 3
#
# Accuracy: [100.     99.638  99.275  99.004  98.279  97.101  95.924  94.112  92.301
#   72.011  50.634  22.464  16.757  13.134]
# ==========================================Attack method pgd  3========================================================
# Adversarial training model: defult method: pgd iters: 12 psr: 0.001 defense against pgd 3
#
# Accuracy: [90.851 84.058 77.989 73.37  69.022 64.946 61.504 57.609 53.804 37.228
#  29.438 18.659 15.127 12.681]
# ==========================================Attack method pgd  3========================================================
# Adversarial training model: defult method: pgd iters: 7 psr: 0.001 defense against pgd 3
#
# Accuracy: [86.413 83.786 82.246 80.072 77.536 75.181 72.645 70.743 68.116 51.54
#  41.938 25.906 20.743 17.12 ]
# ==========================================Attack method pgd  3========================================================
# Adversarial training model: defult method: pgd iters: 4 psr: 0.001 defense against pgd 3
#
# Accuracy: [88.768 86.141 82.518 77.627 72.645 68.569 64.946 60.507 56.884 37.5
#  27.174 15.217 11.685  9.601]
# ==========================================Attack method pgd  3========================================================
# Adversarial training model: defult method: pgd iters: 3 psr: 0.001 defense against pgd 3
#
# Accuracy: [86.594 84.964 82.156 78.533 74.728 71.196 67.391 62.953 58.243 40.217
#  28.986 18.569 14.855 13.225]
# ==========================================Attack method pgd  3========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.001 defense against pgd 3
#
# Accuracy: [93.659 90.489 88.406 86.775 85.417 83.605 82.428 80.797 79.257 66.395
#  55.344 36.322 30.707 25.453]
# ==========================================Attack method pgd  3========================================================
# Adversarial training model: defult method: fgsm iters: None psr: 0.001 defense against pgd 3
#
# Accuracy: [86.413 83.786 82.337 81.159 79.62  77.808 75.906 74.185 72.283 59.783
#  50.272 30.254 21.286 16.486]
# ==========================================Attack method pgd  3========================================================
# Adversarial training model: defult method: pgd iters: 2 psr: 0.001 defense against pgd 3
#
# Accuracy: [91.757 86.866 80.344 75.725 71.377 67.572 64.13  60.598 57.699 40.399
#  30.978 19.022 14.855 13.134]
# ==========================================Attack method pgd  3========================================================
# Adversarial training model: defult method: pgd iters: 6 psr: 0.001 defense against pgd 3
#
# Accuracy: [89.221 85.417 80.525 75.906 71.83  68.388 63.859 59.692 55.888 37.228
#  28.533 17.21  13.768 11.866]
# ==========================================Attack method pgd  3========================================================
# Adversarial training model: defult method: pgd iters: 5 psr: 0.001 defense against pgd 3
#
# Accuracy: [85.417 82.79  78.08  73.732 69.112 64.493 59.783 56.341 52.355 35.236
#  25.996 14.04  12.138  9.33 ]
# ==========================================Attack method pgd  4========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.0005 defense against pgd 4
#
# Accuracy: [100.     99.638  99.275  99.004  98.279  97.101  95.924  94.112  92.301
#   72.011  50.634  22.373  16.757  13.134]
# ==========================================Attack method pgd  4========================================================
# Adversarial training model: defult method: pgd iters: 12 psr: 0.001 defense against pgd 4
#
# Accuracy: [90.851 84.058 77.899 73.37  69.022 64.946 61.413 57.518 53.804 37.047
#  29.529 18.931 15.308 12.772]
# ==========================================Attack method pgd  4========================================================
# Adversarial training model: defult method: pgd iters: 7 psr: 0.001 defense against pgd 4
#
# Accuracy: [86.413 83.786 82.337 80.072 77.536 75.181 72.645 70.833 68.116 51.54
#  41.938 25.906 20.743 17.12 ]
# ==========================================Attack method pgd  4========================================================
# Adversarial training model: defult method: pgd iters: 4 psr: 0.001 defense against pgd 4
#
# Accuracy: [88.768 86.141 82.518 77.627 72.645 68.569 64.946 60.417 56.884 37.5
#  27.083 15.217 11.685  9.692]
# ==========================================Attack method pgd  4========================================================
# Adversarial training model: defult method: pgd iters: 3 psr: 0.001 defense against pgd 4
#
# Accuracy: [86.594 84.964 82.156 78.533 74.728 71.105 67.391 63.043 58.333 40.217
#  28.986 18.569 14.855 13.315]
# ==========================================Attack method pgd  4========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.001 defense against pgd 4
#
# Accuracy: [93.659 90.489 88.406 86.775 85.417 83.605 82.428 80.797 79.257 66.667
#  55.344 36.957 30.616 25.543]
# ==========================================Attack method pgd  4========================================================
# Adversarial training model: defult method: fgsm iters: None psr: 0.001 defense against pgd 4
#
# Accuracy: [86.413 83.786 82.337 81.159 79.62  77.808 75.906 74.185 72.283 59.783
#  50.272 30.254 21.286 16.486]
# ==========================================Attack method pgd  4========================================================
# Adversarial training model: defult method: pgd iters: 2 psr: 0.001 defense against pgd 4
#
# Accuracy: [91.757 86.866 80.344 75.815 71.377 67.663 64.221 60.87  57.518 40.217
#  30.978 19.203 15.127 13.406]
# ==========================================Attack method pgd  4========================================================
# Adversarial training model: defult method: pgd iters: 6 psr: 0.001 defense against pgd 4
#
# Accuracy: [89.221 85.417 80.525 75.906 71.83  68.388 63.859 59.692 55.888 37.228
#  28.714 17.482 13.859 12.047]
# ==========================================Attack method pgd  4========================================================
# Adversarial training model: defult method: pgd iters: 5 psr: 0.001 defense against pgd 4
#
# Accuracy: [85.417 82.79  78.08  73.732 69.112 64.493 59.783 56.341 52.355 35.236
#  25.996 14.04  12.138  9.33 ]
# ==========================================Attack method pgd  5========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.0005 defense against pgd 5
#
# Accuracy: [100.     99.638  99.275  99.004  98.279  97.101  95.924  94.112  92.301
#   72.011  50.634  22.283  16.757  13.134]
# ==========================================Attack method pgd  5========================================================
# Adversarial training model: defult method: pgd iters: 12 psr: 0.001 defense against pgd 5
#
# Accuracy: [90.851 84.058 77.899 73.37  69.022 64.855 61.594 57.609 53.986 37.138
#  29.529 18.207 15.489 12.409]
# ==========================================Attack method pgd  5========================================================
# Adversarial training model: defult method: pgd iters: 7 psr: 0.001 defense against pgd 5
#
# Accuracy: [86.413 83.786 82.337 80.072 77.536 75.181 72.645 70.833 68.116 51.54
#  41.938 25.906 20.743 17.12 ]
# ==========================================Attack method pgd  5========================================================
# Adversarial training model: defult method: pgd iters: 4 psr: 0.001 defense against pgd 5
#
# Accuracy: [88.768 86.141 82.428 77.627 72.645 68.569 64.946 60.417 56.793 37.5
#  27.174 15.127 11.685  9.692]
# ==========================================Attack method pgd  5========================================================
# Adversarial training model: defult method: pgd iters: 3 psr: 0.001 defense against pgd 5
#
# Accuracy: [86.594 84.964 82.156 78.533 74.728 71.105 67.391 63.043 58.333 40.217
#  28.986 18.659 14.855 13.315]
# ==========================================Attack method pgd  5========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.001 defense against pgd 5
#
# Accuracy: [93.659 90.489 88.406 86.775 85.417 83.605 82.428 80.797 79.257 66.667
#  55.344 36.504 30.435 25.362]
# ==========================================Attack method pgd  5========================================================
# Adversarial training model: defult method: fgsm iters: None psr: 0.001 defense against pgd 5
#
# Accuracy: [86.413 83.786 82.337 81.159 79.62  77.808 75.906 74.185 72.283 59.783
#  50.272 30.344 21.286 16.486]
# ==========================================Attack method pgd  5========================================================
# Adversarial training model: defult method: pgd iters: 2 psr: 0.001 defense against pgd 5
#
# Accuracy: [91.757 86.866 80.344 75.815 71.196 67.572 64.13  60.688 57.518 40.399
#  31.069 18.841 14.855 13.315]
# ==========================================Attack method pgd  5========================================================
# Adversarial training model: defult method: pgd iters: 6 psr: 0.001 defense against pgd 5
#
# Accuracy: [89.221 85.417 80.525 75.906 71.83  68.388 63.949 59.692 55.888 37.228
#  28.442 17.391 13.768 11.866]
# ==========================================Attack method pgd  5========================================================
# Adversarial training model: defult method: pgd iters: 5 psr: 0.001 defense against pgd 5
#
# Accuracy: [85.417 82.79  78.08  73.732 69.112 64.493 59.783 56.341 52.355 35.236
#  25.996 14.04  12.228  9.239]
# ==========================================Attack method pgd  6========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.0005 defense against pgd 6
#
# Accuracy: [100.     99.638  99.275  99.004  98.279  97.101  95.924  94.112  92.301
#   72.011  50.634  22.283  16.757  13.134]
# ==========================================Attack method pgd  6========================================================
# Adversarial training model: defult method: pgd iters: 12 psr: 0.001 defense against pgd 6
#
# Accuracy: [90.851 84.058 77.989 73.279 69.022 64.855 61.413 57.428 53.714 37.228
#  29.257 18.388 14.583 12.228]
# ==========================================Attack method pgd  6========================================================
# Adversarial training model: defult method: pgd iters: 7 psr: 0.001 defense against pgd 6
#
# Accuracy: [86.413 83.786 82.246 80.072 77.536 75.181 72.645 70.743 68.116 51.54
#  41.938 25.906 20.743 17.12 ]
# ==========================================Attack method pgd  6========================================================
# Adversarial training model: defult method: pgd iters: 4 psr: 0.001 defense against pgd 6
#
# Accuracy: [88.768 86.141 82.518 77.627 72.645 68.569 64.946 60.417 56.703 37.5
#  27.174 15.036 11.594  9.601]
# ==========================================Attack method pgd  6========================================================
# Adversarial training model: defult method: pgd iters: 3 psr: 0.001 defense against pgd 6
#
# Accuracy: [86.594 84.964 82.156 78.533 74.728 71.196 67.391 63.043 58.333 40.217
#  28.986 18.569 14.855 13.315]
# ==========================================Attack method pgd  6========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.001 defense against pgd 6
#
# Accuracy: [93.659 90.489 88.406 86.775 85.417 83.605 82.428 80.797 79.257 66.757
#  54.891 36.775 30.163 25.725]
# ==========================================Attack method pgd  6========================================================
# Adversarial training model: defult method: fgsm iters: None psr: 0.001 defense against pgd 6
#
# Accuracy: [86.413 83.786 82.337 81.159 79.62  77.808 75.906 74.185 72.283 59.783
#  50.272 30.344 21.286 16.486]
# ==========================================Attack method pgd  6========================================================
# Adversarial training model: defult method: pgd iters: 2 psr: 0.001 defense against pgd 6
#
# Accuracy: [91.757 86.866 80.344 75.815 71.377 67.663 64.312 60.779 57.518 40.399
#  31.25  18.931 15.127 13.315]
# ==========================================Attack method pgd  6========================================================
# Adversarial training model: defult method: pgd iters: 6 psr: 0.001 defense against pgd 6
#
# Accuracy: [89.221 85.417 80.525 75.906 71.83  68.388 63.949 59.692 55.888 37.228
#  28.442 17.391 13.768 11.866]
# ==========================================Attack method pgd  6========================================================
# Adversarial training model: defult method: pgd iters: 5 psr: 0.001 defense against pgd 6
#
# Accuracy: [85.417 82.79  78.08  73.732 69.112 64.493 59.783 56.341 52.355 35.236
#  25.996 14.04  12.138  9.33 ]
# ==========================================Attack method pgd  7========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.0005 defense against pgd 7
#
# Accuracy: [100.     99.638  99.275  99.004  98.279  97.101  95.924  94.112  92.301
#   72.011  50.634  22.283  16.757  13.134]
# ==========================================Attack method pgd  7========================================================
# Adversarial training model: defult method: pgd iters: 12 psr: 0.001 defense against pgd 7
#
# Accuracy: [90.851 84.058 77.989 73.37  69.022 64.946 61.504 57.518 53.804 37.228
#  29.801 18.297 14.946 12.591]
# ==========================================Attack method pgd  7========================================================
# Adversarial training model: defult method: pgd iters: 7 psr: 0.001 defense against pgd 7
#
# Accuracy: [86.413 83.786 82.246 80.072 77.536 75.181 72.645 70.833 68.116 51.54
#  41.938 25.906 20.743 17.12 ]
# ==========================================Attack method pgd  7========================================================
# Adversarial training model: defult method: pgd iters: 4 psr: 0.001 defense against pgd 7
#
# Accuracy: [88.768 86.141 82.518 77.627 72.645 68.569 64.946 60.417 56.884 37.5
#  27.174 15.217 11.685  9.692]
# ==========================================Attack method pgd  7========================================================
# Adversarial training model: defult method: pgd iters: 3 psr: 0.001 defense against pgd 7
#
# Accuracy: [86.594 84.964 82.156 78.533 74.728 71.105 67.391 63.043 58.333 40.127
#  28.986 18.569 14.855 13.225]
# ==========================================Attack method pgd  7========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.001 defense against pgd 7
#
# Accuracy: [93.659 90.489 88.406 86.775 85.417 83.605 82.428 80.797 79.257 66.848
#  55.435 36.504 30.525 25.181]
# ==========================================Attack method pgd  7========================================================
# Adversarial training model: defult method: fgsm iters: None psr: 0.001 defense against pgd 7
#
# Accuracy: [86.413 83.786 82.337 81.159 79.62  77.808 75.906 74.185 72.283 59.783
#  50.272 30.254 21.286 16.486]
# ==========================================Attack method pgd  7========================================================
# Adversarial training model: defult method: pgd iters: 2 psr: 0.001 defense against pgd 7
#
# Accuracy: [91.757 86.866 80.344 75.815 71.286 67.572 64.221 60.598 57.428 40.217
#  30.978 19.022 14.764 13.225]
# ==========================================Attack method pgd  7========================================================
# Adversarial training model: defult method: pgd iters: 6 psr: 0.001 defense against pgd 7
#
# Accuracy: [89.221 85.417 80.525 75.906 71.83  68.388 63.859 59.692 55.888 37.228
#  28.351 17.391 13.768 11.866]
# ==========================================Attack method pgd  7========================================================
# Adversarial training model: defult method: pgd iters: 5 psr: 0.001 defense against pgd 7
#
# Accuracy: [85.417 82.79  78.08  73.732 69.112 64.493 59.783 56.25  52.355 35.236
#  26.087 14.04  12.138  9.239]
# ==========================================Attack method pgd  12========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.0005 defense against pgd 12
#
# Accuracy: [100.     99.638  99.275  99.004  98.279  97.101  95.924  94.112  92.301
#   72.011  50.634  22.373  16.757  13.134]
# ==========================================Attack method pgd  12========================================================
# Adversarial training model: defult method: pgd iters: 12 psr: 0.001 defense against pgd 12
#
# Accuracy: [90.851 84.058 77.989 73.46  69.022 65.036 61.504 57.518 53.714 37.228
#  29.438 18.569 15.217 12.591]
# ==========================================Attack method pgd  12========================================================
# Adversarial training model: defult method: pgd iters: 7 psr: 0.001 defense against pgd 12
#
# Accuracy: [86.413 83.786 82.337 80.072 77.536 75.181 72.645 70.833 68.116 51.54
#  41.938 25.906 20.743 17.12 ]
# ==========================================Attack method pgd  12========================================================
# Adversarial training model: defult method: pgd iters: 4 psr: 0.001 defense against pgd 12
#
# Accuracy: [88.768 86.141 82.428 77.627 72.645 68.569 64.946 60.417 56.884 37.5
#  27.174 15.217 11.685  9.601]
# ==========================================Attack method pgd  12========================================================
# Adversarial training model: defult method: pgd iters: 3 psr: 0.001 defense against pgd 12
#
# Accuracy: [86.594 84.964 82.156 78.533 74.728 71.105 67.391 63.043 58.243 40.127
#  28.986 18.659 14.855 13.225]
# ==========================================Attack method pgd  12========================================================
# Adversarial training model: resnet method: pgd iters: 4 psr: 0.001 defense against pgd 12
#
# Accuracy: [93.659 90.489 88.406 86.775 85.417 83.605 82.428 80.797 79.257 66.757
#  55.344 36.957 30.797 25.996]
# ==========================================Attack method pgd  12========================================================
# Adversarial training model: defult method: fgsm iters: None psr: 0.001 defense against pgd 12
#
# Accuracy: [86.413 83.786 82.337 81.159 79.62  77.808 75.906 74.185 72.283 59.783
#  50.272 30.344 21.286 16.486]
# ==========================================Attack method pgd  12========================================================
# Adversarial training model: defult method: pgd iters: 2 psr: 0.001 defense against pgd 12
#
# Accuracy: [91.757 86.866 80.254 75.906 71.286 67.663 64.312 60.87  57.609 40.58
#  31.341 19.112 14.946 13.315]
# ==========================================Attack method pgd  12========================================================
# Adversarial training model: defult method: pgd iters: 6 psr: 0.001 defense against pgd 12
#
# Accuracy: [89.221 85.417 80.525 75.906 71.83  68.388 63.859 59.692 55.888 37.228
#  28.533 17.482 13.768 11.866]
# ==========================================Attack method pgd  12========================================================
# Adversarial training model: defult method: pgd iters: 5 psr: 0.001 defense against pgd 12
#
# Accuracy: [85.417 82.79  78.08  73.732 69.112 64.493 59.783 56.25  52.355 35.236
#  26.087 14.04  12.138  9.239]

# %%
test_loop(config,psr_current,model,test_dataset,ATK_method,n_iter = iter)

# %%
np.set_printoptions(precision=3)
print(f'Accuracy: {np.asarray(acc_buf)*100}')

# %%
result = loadmat('resultsMat/acc_all_adv_all_l2_pgd.mat',squeeze_me=True)
result.pop('__header__')
result.pop('__version__')
result.pop('__globals__')
# from scipy.io import loadmat
def comp_atk_success_rate(acc_array):
    return (acc_array[0] - acc_array)/acc_array[0]

for method, acc in result.items():
    print( f'{method}:', comp_atk_success_rate(acc) )
